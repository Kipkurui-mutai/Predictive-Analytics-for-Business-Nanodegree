# %% [markdown]
#     Predicted Data is obtained from Alteryx Workflow.

# %%
# Loading Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Loading datasets
customers = pd.read_excel('/content/drive/MyDrive/UDACITY/1. Problem Solving using Advanced Analytics/Project 1.2 Predicting Catalogue Demand/p1-customers.xlsx')
mailinglist = pd.read_excel('/content/drive/MyDrive/UDACITY/1. Problem Solving using Advanced Analytics/Project 1.2 Predicting Catalogue Demand/p1-mailinglist.xlsx')
predicted = pd.read_excel('/content/drive/MyDrive/UDACITY/1. Problem Solving using Advanced Analytics/Project 1.2 Predicting Catalogue Demand/Catalog_predicted.xlsx')

# %%
# Checking the heads
customers.head()
# Out:
#                Name  ... #_Years_as_Customer
# 0     Pamela Wright  ...                   6
# 1     Danell Valdez  ...                   6
# 2  Jessica Rinehart  ...                   3
# 3       Nancy Clark  ...                   6
# 4       Andrea Brun  ...                   2
#
# [5 rows x 12 columns]

# %%
customers.columns
# Out:
# Index(['Name', 'Customer_Segment', 'Customer_ID', 'Address', 'City', 'State',
#        'ZIP', 'Avg_Sale_Amount', 'Store_Number', 'Responded_to_Last_Catalog',
#        'Avg_Num_Products_Purchased', '#_Years_as_Customer'],
#       dtype='object')

# %%
customers.describe()
# Out:
#        Customer_ID  ...  #_Years_as_Customer
# count  2375.000000  ...          2375.000000
# mean   1647.845474  ...             4.500632
# std     962.728105  ...             2.309986
# min       2.000000  ...             1.000000
# 25%     820.500000  ...             2.000000
# 50%    1629.000000  ...             5.000000
# 75%    2492.500000  ...             6.000000
# max    3335.000000  ...             8.000000
#
# [8 rows x 6 columns]

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2375 entries, 0 to 2374
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name                        2375 non-null   object
#  1   Customer_Segment            2375 non-null   object
#  2   Customer_ID                 2375 non-null   int64
#  3   Address                     2375 non-null   object
#  4   City                        2375 non-null   object
#  5   State                       2375 non-null   object
#  6   ZIP                         2375 non-null   int64
#  7   Avg_Sale_Amount             2375 non-null   float64
#  8   Store_Number                2375 non-null   int64
#  9   Responded_to_Last_Catalog   2375 non-null   object
#  10  Avg_Num_Products_Purchased  2375 non-null   int64
#  11  #_Years_as_Customer         2375 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 222.8+ KB

# %%
customers.shape
# Out:
# (2375, 12)

# %%
plt.figure(figsize=(8,6))
plt.scatter(data = customers, x = 'Avg_Num_Products_Purchased', y = 'Avg_Sale_Amount')
plt.title('Avg_Num_Products_Purchased vs Avg_Sale_Amount')
plt.xlabel('Avg_Num_Products_Purchased')
plt.ylabel('Avg_Sale_Amount')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=customers, x = 'Avg_Num_Products_Purchased', y = 'Avg_Sale_Amount', hue = 'Customer_Segment', legend='full')
plt.title('Avg_Num_Products_Purchased vs Avg_Sale_Amount')
plt.savefig("CustomerSegment", facecolor='w', edgecolor='w',orientation='portrait',transparent=False, pad_inches=0.5)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data = customers, x = 'Avg_Num_Products_Purchased', y = 'Avg_Sale_Amount', hue = '#_Years_as_Customer', legend='full')
plt.title('Avg_Num_Products_Purchased vs Avg_Sale_Amount')
plt.savefig("Years", facecolor='w', edgecolor='w', orientation='portrait', transparent=False,  pad_inches=0.1)
